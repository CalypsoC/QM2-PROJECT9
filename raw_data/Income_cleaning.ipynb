# %% [markdown]
# <a href="https://colab.research.google.com/github/CalypsoC/QM2-PROJECT9/blob/main/Income_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7a60862a-64d2-4a93-99a5-b4fcb69fa7dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a60862a-64d2-4a93-99a5-b4fcb69fa7dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('income_Raw.csv')
df.head()
# Out:
#        geoid        name  B19013001  B19013001, Error
# 0  04000US01     Alabama      53913               781
# 1  04000US02      Alaska      77845              2148
# 2  04000US04     Arizona      69056               686
# 3  04000US05    Arkansas      52528              1002
# 4  04000US06  California      84907               542

# %%
df.columns
# Out:
# Index(['geoid', 'name', 'B19013001', 'B19013001, Error'], dtype='object')

# %%
income=df.drop(columns=['geoid','B19013001, Error'])

# %%
income.head()
# Out:
#          name  B19013001
# 0     Alabama      53913
# 1      Alaska      77845
# 2     Arizona      69056
# 3    Arkansas      52528
# 4  California      84907

# %%
new=income.rename(columns={"name":"STATE","B19013001":"Median Household Income"})

# %%
new.info
# Out:
# <bound method DataFrame.info of                    STATE  Median Household Income
# 0                Alabama                    53913
# 1                 Alaska                    77845
# 2                Arizona                    69056
# 3               Arkansas                    52528
# 4             California                    84907
# 5               Colorado                    82254
# 6            Connecticut                    83771
# 7               Delaware                    71091
# 8   District of Columbia                    90088
# 9                Florida                    63062
# 10               Georgia                    66559
# 11                Hawaii                    84857
# 12                 Idaho                    66474
# 13              Illinois                    72205
# 14               Indiana                    62743
# 15                  Iowa                    65600
# 16                Kansas                    64124
# ...

# %%
new.to_csv('Income.csv', index=False)

# %%
files.download('Income.csv')
